# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithkaran3/house-price-regression/blob/main/Houseprice_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # House Price Study in US ( using supply and demand factors)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5a44e0c5-6ca2-4710-8c5e-69e0c67320aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a44e0c5-6ca2-4710-8c5e-69e0c67320aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Housing_data - data.csv to Housing_data - data.csv

# %% [markdown]
# In this model, 6 factors namely population, monthly supply of homes, house permits, mortgage rate, gdp and unemployment rates are used for the analysis of House prices.
#
#
# Demand Factors:
# - Population
# - Unemploment rate
# - mortgage rate
# - gdp
#
# supply factors:
# - monthly supply of homes
# - new house permits

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib

# %%
df = pd.read_csv('Housing_data - data.csv')

# %%
df.tail(20)
# Out:
#           date  target_price_index  population  monthly_supply_houses  \
# 244   1/5/2020             217.810    329894.0                    5.3
# 245   1/6/2020             218.356    330038.0                    4.3
# 246   1/7/2020             219.899    330199.0                    3.6
# 247   1/8/2020             222.735    330368.0                    3.5
# 248   1/9/2020             225.954    330535.0                    3.5
# 249  1/10/2020             229.442    330692.0                    3.5
# 250  1/11/2020             232.656    330829.0                    4.0
# 251  1/12/2020             235.583    330924.0                    3.8
# 252   1/1/2021             238.530    330968.0                    3.6
# 253        NaN                 NaN         NaN                    NaN
# 254        NaN                 NaN         NaN                    NaN
# 255        NaN                 NaN         NaN                    NaN
# ...

# %%
df2 = df.dropna()
df2.tail(5)
# Out:
#           date  target_price_index  population  monthly_supply_houses  \
# 248   1/9/2020             225.954    330535.0                    3.5
# 249  1/10/2020             229.442    330692.0                    3.5
# 250  1/11/2020             232.656    330829.0                    4.0
# 251  1/12/2020             235.583    330924.0                    3.8
# 252   1/1/2021             238.530    330968.0                    3.6
#
#      new_permits_thousands  mortgage_rate  gdp_monthly  unempoyment_rate
# 248                 1589.0           4.45       95.949               7.9
# 249                 1595.0           4.41       96.081               6.9
# 250                 1696.0           4.41       96.210               6.7
# 251                 1758.0           4.08       96.451               6.7
# 252                 1883.0           4.14       96.692               6.4

# %%
df2.dtypes
# Out:
# date                      object
# target_price_index       float64
# population               float64
# monthly_supply_houses    float64
# new_permits_thousands    float64
# mortgage_rate            float64
# gdp_monthly              float64
# unempoyment_rate         float64
# dtype: object

# %%
df3 = df2.drop(columns=['date'], axis=1)

# %% [markdown]
# # Feature Scaling: Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df4=pd.DataFrame(scaler.fit_transform(df3), columns=df3.columns, index=df3.index) 
df4
# Out:
#      target_price_index  population  monthly_supply_houses  \
# 0              0.000000    0.000000               0.091954
# 1              0.005704    0.004330               0.091954
# 2              0.011415    0.008981               0.091954
# 3              0.017177    0.013631               0.103448
# 4              0.022649    0.018302               0.103448
# ..                  ...         ...                    ...
# 248            0.908855    0.991320               0.000000
# 249            0.934134    0.994467               0.000000
# 250            0.957428    0.997214               0.057471
# 251            0.978642    0.999118               0.034483
# 252            1.000000    1.000000               0.011494
#
#      new_permits_thousands  mortgage_rate  gdp_monthly  unempoyment_rate
# 0                 0.693714       0.911488     0.970310          0.044643
# 1                 0.673714       0.930320     0.975683          0.053571
# ...

# %% [markdown]
# # Train- test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df4.drop(columns="target_price_index", axis=1), df4["target_price_index"], 
                                                    test_size= 0.20, random_state=40)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train, y_train)
lr_clf.score(X_test, y_test)
# Out:
# 0.9728269548202986

# %%
X = df4.drop(['target_price_index'], axis = 'columns')

# %%
y = df2.target_price_index

# %% [markdown]
# # K Fold Cross validation to measure accuracy of Regression models

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit( n_splits = 5, test_size=0.2, random_state=0  )

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([0.95376126, 0.95467796, 0.97521828, 0.95047961, 0.97182698])

# %% [markdown]
# # Find best model using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso

from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py:145: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py:145: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# ...

# %% [markdown]
# # OLS

# %%
import statsmodels.api as sm

# %%
result = sm.OLS(y_train, X_train).fit()

# %%
print(result.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:     target_price_index   R-squared (uncentered):                   0.987
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              2547.
# Date:                Fri, 09 Sep 2022   Prob (F-statistic):                   5.41e-183
# Time:                        10:04:39   Log-Likelihood:                          295.71
# No. Observations:                 202   AIC:                                     -579.4
# Df Residuals:                     196   BIC:                                     -559.6
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Conclusion
#
# Prediction Model: Linear regression
# Accuaracy :97.18
#
# Positively correlated variables - population, monthly_supply_homes, new_permits
#
#
# Negatively correlated variables - mortgage_rate, gdp_monthly, unempoyment_rate
